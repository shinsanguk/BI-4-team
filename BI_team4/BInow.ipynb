# %%
import pandas as pd 
# dat = pd.read_csv('file.csv', thousands = ',', index_col = 0, names = ['col1', 'col2', 'col3'], encoding = 'utf-8')
# dat.head() 
# dat.columns # 열 이름 출력 dat.rename(columns = {dat.columns[0] : '명칭'}, inplace = True ) # 열 이름 변경

# %%
data = pd.read_csv("./g.csv")

# %%
list(data)
# Out:
# ['타임스탬프',
#  ' [스타크래프트 (starcraft)]',
#  ' [롤 (league of legends)]',
#  ' [메이플스토리 (maple story)]',
#  ' [오버워치 (OverWatch)]',
#  ' [서든어택 (Sudden Attack)]',
#  ' [배틀그라운드 (PUBG)]',
#  ' [마인크래프트 (MineCraft)]',
#  ' [던전 앤 파이터 (Dungeons & Fighters)]',
#  ' [포트나이트 (Fortnite)]',
#  ' [카트라이더 (Cart Rider)]',
#  ' [월드 오브 워크래프트 (WoW)]',
#  ' [사이퍼즈 (Cyphers)]',
#  ' [하스스톤 (Hearth Stone)]',
#  ' [디아블로 (Diablo)]',
#  ' [GTA]',
#  ' [리니지 (Lineage)]',
#  ' [검은사막 (Black Desert)]',
#  ' [크레이지아케이드 (Crazy Arcade)]',
#  ' [카운터스트라이크 (Counter Strike)]',
#  ' [피파온라인 (FIFA Online)]',
#  ' [블레이드 앤 소울 (Blades & Souls)]',
#  ' [FM]',
#  ' [로스트아크 (Lostark)]',
#  ' [포켓몬고 (Pokemon GO)]',
#  ' [앵그리버드 (angry bird)]']

# %%
data.columns
# Out:
# Index(['타임스탬프', ' [스타크래프트 (starcraft)]', ' [롤 (league of legends)]',
#        ' [메이플스토리 (maple story)]', ' [오버워치 (OverWatch)]',
#        ' [서든어택 (Sudden Attack)]', ' [배틀그라운드 (PUBG)]', ' [마인크래프트 (MineCraft)]',
#        ' [던전 앤 파이터 (Dungeons & Fighters)]', ' [포트나이트 (Fortnite)]',
#        ' [카트라이더 (Cart Rider)]', ' [월드 오브 워크래프트 (WoW)]', ' [사이퍼즈 (Cyphers)]',
#        ' [하스스톤 (Hearth Stone)]', ' [디아블로 (Diablo)]', ' [GTA]',
#        ' [리니지 (Lineage)]', ' [검은사막 (Black Desert)]',
#        ' [크레이지아케이드 (Crazy Arcade)]', ' [카운터스트라이크 (Counter Strike)]',
#        ' [피파온라인 (FIFA Online)]', ' [블레이드 앤 소울 (Blades & Souls)]', ' [FM]',
#        ' [로스트아크 (Lostark)]', ' [포켓몬고 (Pokemon GO)]', ' [앵그리버드 (angry bird)]'],
#       dtype='object')

# %%
data=data.drop('타임스탬프',axis=1)

# %%
data
# Out:
#      [스타크래프트 (starcraft)]   [롤 (league of legends)]   [메이플스토리 (maple story)]  \
# 0                     5.0                       NaN                      3.0
# 1                     3.0                       5.0                      3.0
# 2                     5.0                       4.0                      4.0
# 3                     5.0                       5.0                      3.0
# 4                     4.0                       2.0                      1.0
# 5                     3.0                       5.0                      1.0
# 6                     2.0                       3.0                      4.0
# 7                     3.0                       NaN                      NaN
# 8                     5.0                       5.0                      1.0
# 9                     4.0                       3.0                      2.0
# 10                    1.0                       5.0                      4.0
# ...

# %%
data_dict = {}

# %%
temp = float('nan')

# %%
for i in range(len(data)):
    temp_dict = {}
    for _list in list(data):
        # print(_list)
        if not math.isnan(data[_list][i]):
            temp_dict[_list]=data[_list][i]
    data_dict[i]=temp_dict

# %%
data_dict
# Out:
# {0: {' [스타크래프트 (starcraft)]': 5.0,
#   ' [메이플스토리 (maple story)]': 3.0,
#   ' [오버워치 (OverWatch)]': 4.0,
#   ' [서든어택 (Sudden Attack)]': 2.0,
#   ' [배틀그라운드 (PUBG)]': 5.0,
#   ' [마인크래프트 (MineCraft)]': 5.0,
#   ' [카트라이더 (Cart Rider)]': 3.0,
#   ' [월드 오브 워크래프트 (WoW)]': 4.0,
#   ' [사이퍼즈 (Cyphers)]': 3.0,
#   ' [하스스톤 (Hearth Stone)]': 4.0,
#   ' [GTA]': 4.0,
#   ' [검은사막 (Black Desert)]': 4.0,
#   ' [카운터스트라이크 (Counter Strike)]': 4.0,
#   ' [피파온라인 (FIFA Online)]': 3.0,
#   ' [로스트아크 (Lostark)]': 4.0,
#   ' [포켓몬고 (Pokemon GO)]': 5.0,
#   ' [앵그리버드 (angry bird)]': 4.0},
#  1: {' [스타크래프트 (starcraft)]': 3.0,
#   ' [롤 (league of legends)]': 5.0,
#   ' [메이플스토리 (maple story)]': 3.0,
#   ' [오버워치 (OverWatch)]': 1.0,
#   ' [서든어택 (Sudden Attack)]': 3.0,
#   ' [카트라이더 (Cart Rider)]': 4.0,
#   ' [크레이지아케이드 (Crazy Arcade)]': 4.0,
#   ' [피파온라인 (FIFA Online)]': 4.0,
#   ' [앵그리버드 (angry bird)]': 4.0},
#  2: {' [스타크래프트 (starcraft)]': 5.0,
#   ' [롤 (league of legends)]': 4.0,
#   ' [메이플스토리 (maple story)]': 4.0,
# ...
